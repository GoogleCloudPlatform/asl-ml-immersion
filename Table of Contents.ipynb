# %% [markdown]
# ## ASL Labs Table of Contents

# %% [markdown]
# ### [1.3_generalization_lab](1.3_generalization_lab)
#
# *  [create_datasets.ipynb](1.3_generalization_lab/create_datasets.ipynb) - Explore and create ML datasets
#
# <br>
# ### [1.4_tensorflow_lab](1.4_tensorflow_lab)
#
# *  [a_tfstart.ipynb](1.4_tensorflow_lab/a_tfstart.ipynb) - Getting started with TensorFlow
#
# *  [b_estimator.ipynb](1.4_tensorflow_lab/b_estimator.ipynb) - Machine Learning using tf.estimator
#
# *  [c_batched.ipynb](1.4_tensorflow_lab/c_batched.ipynb) -   Refactoring to add batching and feature-creation
#
# *  [d_traineval.ipynb](1.4_tensorflow_lab/d_traineval.ipynb) -   Distributed training and monitoring
#
# *  [e_cloudmle.ipynb](1.4_tensorflow_lab/e_cloudmle.ipynb) - Scaling up ML using Cloud ML Engine
#
# *  [taxifare](1.4_tensorflow_lab/taxifare)
#
# <br>
# ### [1.5_features_lab](1.5_features_lab)
#
# *  [a_features.ipynb](1.5_features_lab/a_features.ipynb) - Trying out features
#
# <br>
# ### [2.1_transforms_lab](2.1_transforms_lab)
#
# *  [feateng.ipynb](2.1_transforms_lab/feateng.ipynb) - Feature Engineering
#
# <br>
# ### [2.2_artandscience_lab](2.2_artandscience_lab)
#
# *  [a_handtuning.ipynb](2.2_artandscience_lab/a_handtuning.ipynb) - Hand tuning hyperparameters
#
# *  [b_hyperparam.ipynb](2.2_artandscience_lab/b_hyperparam.ipynb) - Hyperparameter tuning with Cloud ML Engine
#
# *  [c_neuralnetwork.ipynb](2.2_artandscience_lab/c_neuralnetwork.ipynb) - Neural Network
#
# *  [d_customestimator.ipynb](2.2_artandscience_lab/d_customestimator.ipynb) - Time series prediction using RNNs, with TensorFlow and Cloud ML Engine
#
# <br>
# ### [2.4_endtoend_lab](2.4_endtoend_lab)
#
# *  [1_explore.ipynb](2.4_endtoend_lab/1_explore.ipynb) -   Exploring natality dataset
#
# *  [2_sample.ipynb](2.4_endtoend_lab/2_sample.ipynb) -   Creating a sampled dataset
#
# *  [3_tensorflow.ipynb](2.4_endtoend_lab/3_tensorflow.ipynb) - Creating TensorFlow model
#
# *  [4_preproc.ipynb](2.4_endtoend_lab/4_preproc.ipynb) - Preprocessing using Dataflow
#
# *  [5_train.ipynb](2.4_endtoend_lab/5_train.ipynb) - Training on Cloud ML Engine
#
# *  [6_deploy.ipynb](2.4_endtoend_lab/6_deploy.ipynb) - Deploying and predicting with model
#
# *  [babyweight](2.4_endtoend_lab/babyweight)
#
# <br>
# ### [2.5_servingml_lab](2.5_servingml_lab)
#
# <br>
# ### [3.1_image_lab](3.1_image_lab)
#
# *  [flowers_fromscratch.ipynb](3.1_image_lab/flowers_fromscratch.ipynb) - Flowers Image Classification with TensorFlow on Cloud ML Engine
#
# *  [mnist_estimator.ipynb](3.1_image_lab/mnist_estimator.ipynb) - MNIST Image Classification with TensorFlow on Cloud ML Engine
#
# *  [mnist_models.ipynb](3.1_image_lab/mnist_models.ipynb) - MNIST Image Classification with TensorFlow on Cloud ML Engine
#
# *  [flowersmodel](3.1_image_lab/flowersmodel)
#
# *  [mnistmodel](3.1_image_lab/mnistmodel)
#
# <br>
# ### [3.2_sequence_lab](3.2_sequence_lab)
#
# *  [poetry.ipynb](3.2_sequence_lab/poetry.ipynb) - Text generation using tensor2tensor on Cloud ML Engine
#
# *  [sinewaves.ipynb](3.2_sequence_lab/sinewaves.ipynb) - Time series prediction, end-to-end
#
# *  [temperature.ipynb](3.2_sequence_lab/temperature.ipynb) - Time-series prediction (temperature from weather stations)
#
# *  [txtcls1.ipynb](3.2_sequence_lab/txtcls1.ipynb) - Text Classification using TensorFlow on Cloud ML Engine
#
# *  [txtcls2.ipynb](3.2_sequence_lab/txtcls2.ipynb) - Text Classification using TensorFlow on Cloud ML Engine (using pretrained embedding)
#
# *  [word2vec.ipynb](3.2_sequence_lab/word2vec.ipynb) - Creating a custom Word2Vec embedding on your data
#
# <br>
# ### [3.3_recommendation_lab](3.3_recommendation_lab)
#
# *  [content.ipynb](3.3_recommendation_lab/content.ipynb) - Content-based recommendation system
#
# *  [wals.ipynb](3.3_recommendation_lab/wals.ipynb) - Collaborative filtering on Google Analytics data
#
# *  [wals](3.3_recommendation_lab/wals)
#
# <br>

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### [1.1_welcome_soln](1.1_welcome_soln)
#
# *  [data_analysis.ipynb](1.1_welcome_soln/data_analysis.ipynb) - Data Analysis using Datalab and BigQuery
#
# <br>
# ### [1.2_googleml_soln](1.2_googleml_soln)
#
# *  [mlapis.ipynb](1.2_googleml_soln/mlapis.ipynb) - Using Machine Learning APIs
#
# <br>
# ### [1.3_generalization_soln](1.3_generalization_soln)
#
# *  [create_datasets.ipynb](1.3_generalization_soln/create_datasets.ipynb) - Explore and create ML datasets
#
# *  [repeatable_splitting.ipynb](1.3_generalization_soln/repeatable_splitting.ipynb) - Repeatable splitting
#
# <br>
# ### [1.4_tensorflow_soln](1.4_tensorflow_soln)
#
# *  [a_tfstart.ipynb](1.4_tensorflow_soln/a_tfstart.ipynb) - Getting started with TensorFlow
#
# *  [b_estimator.ipynb](1.4_tensorflow_soln/b_estimator.ipynb) - Machine Learning using tf.estimator
#
# *  [c_batched.ipynb](1.4_tensorflow_soln/c_batched.ipynb) -   Refactoring to add batching and feature-creation
#
# *  [d_traineval.ipynb](1.4_tensorflow_soln/d_traineval.ipynb) -   Distributed training and monitoring
#
# *  [debug_demo.ipynb](1.4_tensorflow_soln/debug_demo.ipynb) - Demonstrates some common TensorFlow errors
#
# *  [e_cloudmle.ipynb](1.4_tensorflow_soln/e_cloudmle.ipynb) - Scaling up ML using Cloud ML Engine
#
# *  [taxifare](1.4_tensorflow_soln/taxifare)
#
# <br>
# ### [1.5_features_soln](1.5_features_soln)
#
# *  [a_features.ipynb](1.5_features_soln/a_features.ipynb) - Trying out features
#
# <br>
# ### [2.1_transforms_soln](2.1_transforms_soln)
#
# *  [feateng.ipynb](2.1_transforms_soln/feateng.ipynb) - Feature Engineering
#
# <br>
# ### [2.2_artandscience_soln](2.2_artandscience_soln)
#
# *  [a_handtuning.ipynb](2.2_artandscience_soln/a_handtuning.ipynb) - Hand tuning hyperparameters
#
# *  [b_hyperparam.ipynb](2.2_artandscience_soln/b_hyperparam.ipynb) - Hyperparameter tuning with Cloud ML Engine
#
# *  [c_neuralnetwork.ipynb](2.2_artandscience_soln/c_neuralnetwork.ipynb) - Neural Network
#
# *  [d_customestimator.ipynb](2.2_artandscience_soln/d_customestimator.ipynb) - Time series prediction using RNNs, with TensorFlow and Cloud ML Engine
#
# <br>
# ### [2.4_endtoend_soln](2.4_endtoend_soln)
#
# *  [1_explore.ipynb](2.4_endtoend_soln/1_explore.ipynb) -   Exploring natality dataset
#
# *  [2_sample.ipynb](2.4_endtoend_soln/2_sample.ipynb) -   Creating a sampled dataset
#
# *  [3_tensorflow.ipynb](2.4_endtoend_soln/3_tensorflow.ipynb) - Creating TensorFlow model
#
# *  [4_preproc.ipynb](2.4_endtoend_soln/4_preproc.ipynb) - Preprocessing using Dataflow
#
# *  [4_preproc_tft.ipynb](2.4_endtoend_soln/4_preproc_tft.ipynb) - Preprocessing using tf.transform and Dataflow
#
# *  [5_train.ipynb](2.4_endtoend_soln/5_train.ipynb) - Training on Cloud ML Engine
#
# *  [6_deploy.ipynb](2.4_endtoend_soln/6_deploy.ipynb) - Deploying and predicting with model
#
# *  [babyweight](2.4_endtoend_soln/babyweight)
#
# <br>
# ### [2.5_servingml_soln](2.5_servingml_soln)
#
# <br>
# ### [3.1_image_soln](3.1_image_soln)
#
# *  [flowers_fromscratch.ipynb](3.1_image_soln/flowers_fromscratch.ipynb) - Flowers Image Classification with TensorFlow on Cloud ML Engine
#
# *  [mnist_estimator.ipynb](3.1_image_soln/mnist_estimator.ipynb) - MNIST Image Classification with TensorFlow on Cloud ML Engine
#
# *  [mnist_models.ipynb](3.1_image_soln/mnist_models.ipynb) - MNIST Image Classification with TensorFlow on Cloud ML Engine
#
# *  [flowersmodel](3.1_image_soln/flowersmodel)
#
# *  [mnistmodel](3.1_image_soln/mnistmodel)
#
# <br>
# ### [3.2_sequence_soln](3.2_sequence_soln)
#
# *  [poetry.ipynb](3.2_sequence_soln/poetry.ipynb) - Text generation using tensor2tensor on Cloud ML Engine
#
# *  [sinewaves.ipynb](3.2_sequence_soln/sinewaves.ipynb) - Time series prediction, end-to-end
#
# *  [temperature.ipynb](3.2_sequence_soln/temperature.ipynb) - Time-series prediction (temperature from weather stations)
#
# *  [txtcls1.ipynb](3.2_sequence_soln/txtcls1.ipynb) - Text Classification using TensorFlow on Cloud ML Engine
#
# *  [txtcls2.ipynb](3.2_sequence_soln/txtcls2.ipynb) - Text Classification using TensorFlow on Cloud ML Engine (using pretrained embedding)
#
# *  [word2vec.ipynb](3.2_sequence_soln/word2vec.ipynb) - Creating a custom Word2Vec embedding on your data
#
# <br>
# ### [3.3_recommendation_soln](3.3_recommendation_soln)
#
# *  [content.ipynb](3.3_recommendation_soln/content.ipynb) - Content-based recommendation system
#
# *  [wals.ipynb](3.3_recommendation_soln/wals.ipynb) - Collaborative filtering on Google Analytics data
#
# *  [wals](3.3_recommendation_soln/wals)
#
# <br>
