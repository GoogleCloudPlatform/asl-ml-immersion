# %%
# !saved_model_cli
# Out:
# /bin/bash: line 1: saved_model_cli: command not found

# %%
PATH = %env PATH
# %env PATH=/home/jupyter/asl-ml-immersion/asl_c/.venv/bin:{PATH}
# Out:
# env: PATH=/home/jupyter/asl-ml-immersion/asl_agent/.venv/bin:/usr/local/cuda/bin:/opt/conda/bin:/opt/conda/condabin:/usr/local/bin:/usr/bin:/bin:/usr/local/games:/usr/games:/usr/local/sbin
